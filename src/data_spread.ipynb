# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../dataset/dataset_kematangan_tapai_cleaned.csv')

# %%
data.head
print(data.info())
data.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1251 entries, 0 to 1250
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1251 non-null   int64
#  1   suhu               1251 non-null   float64
#  2   kelembaban         1251 non-null   float64
#  3   jam                1251 non-null   int64
#  4   kadar_gas          1251 non-null   float64
#  5   status_kematangan  1251 non-null   str
# dtypes: float64(3), int64(2), str(1)
# memory usage: 58.8 KB
# None
#    Unnamed: 0   suhu  kelembaban  jam  kadar_gas status_kematangan
# 0           0  28.73       78.77    1       0.02      belum matang
# 1           1  28.51       78.62    2       0.01      belum matang
# 2           2  28.33       78.22    3       0.01      belum matang
# 3           3  29.20       78.46    4       0.01      belum matang
# 4           4  28.42       78.65    5       0.00      belum matang

# %%
palette = {'belum matang': '#3498db', 'matang': '#2ecc71', 'terlalu matang': '#e74c3c'}

# %%
data = data.loc[:, ['jam', 'suhu', 'kelembaban', 'kadar_gas', 'status_kematangan']]
correlations = data[['jam', 'suhu', 'kelembaban', 'kadar_gas']].corr()

sns.heatmap(correlations, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
for feature in ['jam', 'suhu', 'kelembaban']:
    plt.figure()
    ax = sns.scatterplot(data=data, x=feature, y='kadar_gas', hue='status_kematangan', palette=palette)
    plt.show()

# %%
for feature in ['kadar_gas', 'jam', 'suhu', 'kelembaban']:
    plt.figure()
    sns.boxplot(data=data, x=feature, y='status_kematangan', hue='status_kematangan', palette=palette)
    plt.show()
